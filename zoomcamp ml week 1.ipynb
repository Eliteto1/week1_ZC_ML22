# %%
#zoom camp 2022

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\user\\elite_python_learning'

# %%
#homework intro

# %%
#question 1

import numpy as np
np.version.version
# Out:
# '1.20.3'

# %%
import pandas as pd

# %%
car_price_data = pd.read_csv("car_price_data.csv")
car_price_data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
#question 2

#ans = 11914

# %%
#question 3
#Who are the most frequent car manufacturers (top-3) according to the dataset?

#answer = "Chevrolet, Ford, Volkswagen"
car_price_data['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
#question 4
#What's the number of unique Audi car models in the dataset?

#ans = 34
car_price_data[
    car_price_data["Make"] == "Audi" 
].nunique()
# Out:
# Make                   1
# Model                 34
# Year                  20
# Engine Fuel Type       5
# Engine HP             40
# Engine Cylinders       6
# Transmission Type      3
# Driven_Wheels          2
# Number of Doors        2
# Market Category       15
# Vehicle Size           3
# Vehicle Style          6
# highway MPG           23
# city mpg              18
# Popularity             1
# MSRP                 234
# dtype: int64

# %%
#Question 5
#How many columns in the dataset have missing values?

# answer is 5colomns
car_price_data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#Question 6
#Find the median value of "Engine Cylinders" column in the dataset.
#Next, calculate the most frequent value of the same "Engine Cylinders".
#Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.
#Now, calculate the median value of "Engine Cylinders" once again.

# %%
#Find the median value of "Engine Cylinders" column in the dataset.
car_price_data['Engine Cylinders'].median()
# Out:
# 6.0

# %%
#calculate the most frequent value of the same "Engine Cylinders"
car_price_data['Engine Cylinders'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
#Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.
fillmissing = car_price_data['Engine Cylinders'].fillna(4.0)
fillmissing
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
#Now, calculate the median value of "Engine Cylinders" once again.
fillmissing.median()
# Out:
# 6.0

# %%
#Question 7
#Select all the "Lotus" cars from the dataset.
#Select only columns "Engine HP", "Engine Cylinders".
#Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).
#Get the underlying NumPy array. Let's call it X.
#Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
#Invert XTX.
#Create an array y with values [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800].
#Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
#What's the value of the first element of w?
#Note: You just implemented linear regression. We'll talk about it in the next lesson.

# %%
#Select all the "Lotus" cars from the dataset.
car_price_data[
    car_price_data["Make"] == "Lotus"
]
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
#Select only columns "Engine HP", "Engine Cylinders".
hp_cylinder = car_price_data[['Engine HP', 'Engine Cylinders']]
hp_cylinder
# Out:
#        Engine HP  Engine Cylinders
# 0          335.0               6.0
# 1          300.0               6.0
# 2          300.0               6.0
# 3          230.0               6.0
# 4          230.0               6.0
# ...          ...               ...
# 11909      300.0               6.0
# 11910      300.0               6.0
# 11911      300.0               6.0
# 11912      300.0               6.0
# 11913      221.0               6.0
#
# [11914 rows x 2 columns]

# %%
#Now drop all duplicated rows using drop_duplicates method 
remove_dup =hp_cylinder.drop_duplicates(keep = False)
remove_dup
# Out:
#        Engine HP  Engine Cylinders
# 622        661.0              12.0
# 670        402.0              12.0
# 720        535.0              12.0
# 736        300.0               4.0
# 761        372.0              12.0
# 963        500.0               6.0
# 1132       500.0              12.0
# 1341       152.0               6.0
# 1431       456.0               8.0
# 2061       451.0               8.0
# 2166       553.0               8.0
# 2167       453.0               8.0
# 2534       102.0               4.0
# 2858       572.0               8.0
# 3522       435.0              12.0
# 4024       660.0              12.0
# 4467       240.0               8.0
# 4793       123.0               3.0
# 5205       361.0               8.0
# 5286       362.0               8.0
# 5601       565.0               6.0
# 5777       580.0              10.0
# 5778         NaN               NaN
# 6249        66.0               3.0
# 6320       303.0               4.0
# 6436       424.0               6.0
# ...

# %%
#Get the underlying NumPy array. Let's call it X.
X =np.array([[1, 2, 3], [4, 5, 6], [4,5,7]])

X
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [4, 5, 7]])

# %%
#transpose of X
XT = np.transpose(x)
XT
# Out:
# array([[1, 4, 4],
#        [2, 5, 5],
#        [3, 6, 7]])

# %%
#Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
XTX = XT*X
XTX
# Out:
# array([[ 1,  8, 12],
#        [ 8, 25, 30],
#        [12, 30, 49]])

# %%
#Invert XTX.
inverse_XTX =(np.linalg.inv(XTX))
inverse_XTX
# Out:
# array([[-0.49923195,  0.04915515,  0.0921659 ],
#        [ 0.04915515,  0.14592934, -0.10138249],
#        [ 0.0921659 , -0.10138249,  0.05990783]])

# %%
#Create an array y with values [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800].
y = np.array([[1100, 800, 750], [850, 1300, 1000], [1000, 1300, 800]])
y
# Out:
# array([[1100,  800,  750],
#        [ 850, 1300, 1000],
#        [1000, 1300,  800]])

# %%
#Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
k = inverse_XTX * XT
k
# Out:
# array([[-0.49923195,  0.19662058,  0.36866359],
#        [ 0.09831029,  0.7296467 , -0.50691244],
#        [ 0.2764977 , -0.60829493,  0.41935484]])

# %%
#Call the result w.
w = y * k
w
# Out:
# array([[-549.15514593,  157.29646697,  276.49769585],
#        [  83.56374808,  948.54070661, -506.9124424 ],
#        [ 276.49769585, -790.78341014,  335.48387097]])

# %%
#What's the value of the first element of w?
# ANS = -549.15514593
